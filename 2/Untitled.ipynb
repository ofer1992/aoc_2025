// %%
import fs from "node:fs";

// %%
fs.readFileSync("input.txt")
// Out:
// <Buffer 33 32 39 39 31 34 33 2d 33 33 37 38 30 33 31 2c 39 37 32 39 30 2d 31 33 31 31 35 36 2c 35 32 35 34 38 35 2d 36 36 30 39 34 31 2c 37 36 30 36 2d 31 30 ... 455 more bytes>
